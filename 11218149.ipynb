# %%
# !nvidia-smi
# Out:
# Sat Nov  1 11:29:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/
# Out:
# /content/drive

# %%
# %ls
# Out:
# MyDrive/  Shareddrives/

# %%
# %cd MyDrive/colab
# Out:
# /content/drive/MyDrive/colab

# %%
# %ls
# Out:
# mask/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17646, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 17646 (delta 13), reused 8 (delta 8), pack-reused 17601 (from 3)
# Receiving objects: 100% (17646/17646), 16.99 MiB | 15.13 MiB/s, done.
# Resolving deltas: 100% (11989/11989), done.

# %%
# %ls
# Out:
# mask/  yolov5/

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/colab/yolov5

# %%
# !python train.py --data ../mask/data.yaml --epochs 300 --weights '' --cfg models/yolov5s.yaml --batch-size 16
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#      37/299      4.19G    0.07494    0.08971    0.01678        211        640:  57% 4/7 [00:01<00:00,  3.31it/s]/content/drive/MyDrive/colab/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      37/299      4.19G    0.07305    0.08655    0.01587        120        640:  71% 5/7 [00:01<00:01,  2.00it/s]/content/drive/MyDrive/colab/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      37/299      4.19G    0.07459    0.08529     0.0171        164        640:  86% 6/7 [00:02<00:00,  2.27it/s]/content/drive/MyDrive/colab/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# %pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.9 MB/s eta 0:00:00
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source data/images/
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=data/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-444-g1f1e7b90 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 /content/drive/MyDrive/colab/yolov5/data/images/bus.jpg: 640x480 1 mask, 2 no-masks, 48.1ms
# image 2/2 /content/drive/MyDrive/colab/yolov5/data/images/zidane.jpg: 384x640 1 mask, 1 no-mask, 51.6ms
# Speed: 0.7ms pre-process, 49.8ms inference, 39.1ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/exp5/bus.jpg')
